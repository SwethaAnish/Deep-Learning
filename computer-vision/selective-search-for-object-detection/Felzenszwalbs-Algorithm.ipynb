# %%
#import the libraries
import skimage.segmentation
from matplotlib import pyplot as plt

# %%
input_image = plt.imread("D:\SWETHA\LEARNING\python\white_flowers.png")
plt.imshow(input_image)

# %%
#50 segments
result1 = skimage.segmentation.felzenszwalb(input_image, scale=50)
plt.imshow(result1)
# Out:
# c:\Users\F85SU00\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: RuntimeWarning: Got image with third dimension of 4. This image will be interpreted as a multichannel 2d image, which may not be intended.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#1000 segments
result2 = skimage.segmentation.felzenszwalb(image=input_image, scale=1000)
plt.imshow(result2)
